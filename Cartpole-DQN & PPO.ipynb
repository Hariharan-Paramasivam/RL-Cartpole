# %%
# !pip install gym[classic_control]
# !pip install stable_baselines3
# Out:
# Requirement already satisfied: gym[classic_control] in c:\users\harih\anaconda3\envs\rl\lib\site-packages (0.21.0)
# Requirement already satisfied: cloudpickle>=1.2.0 in c:\users\harih\anaconda3\envs\rl\lib\site-packages (from gym[classic_control]) (2.1.0)
# Requirement already satisfied: numpy>=1.18.0 in c:\users\harih\anaconda3\envs\rl\lib\site-packages (from gym[classic_control]) (1.23.1)
# Requirement already satisfied: pyglet>=1.4.0 in c:\users\harih\anaconda3\envs\rl\lib\site-packages (from gym[classic_control]) (1.5.26)
# Requirement already satisfied: stable_baselines3 in c:\users\harih\anaconda3\envs\rl\lib\site-packages (1.6.0)
# Requirement already satisfied: numpy in c:\users\harih\anaconda3\envs\rl\lib\site-packages (from stable_baselines3) (1.23.1)
# Requirement already satisfied: pandas in c:\users\harih\anaconda3\envs\rl\lib\site-packages (from stable_baselines3) (1.4.3)
# Requirement already satisfied: matplotlib in c:\users\harih\anaconda3\envs\rl\lib\site-packages (from stable_baselines3) (3.5.3)
# Requirement already satisfied: cloudpickle in c:\users\harih\anaconda3\envs\rl\lib\site-packages (from stable_baselines3) (2.1.0)
# Requirement already satisfied: torch>=1.11 in c:\users\harih\anaconda3\envs\rl\lib\site-packages (from stable_baselines3) (1.12.1)
# Requirement already satisfied: gym==0.21 in c:\users\harih\anaconda3\envs\rl\lib\site-packages (from stable_baselines3) (0.21.0)
# Requirement already satisfied: typing-extensions in c:\users\harih\anaconda3\envs\rl\lib\site-packages (from torch>=1.11->stable_baselines3) (4.3.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\harih\anaconda3\envs\rl\lib\site-packages (from matplotlib->stable_baselines3) (21.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\harih\anaconda3\envs\rl\lib\site-packages (from matplotlib->stable_baselines3) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\harih\anaconda3\envs\rl\lib\site-packages (from matplotlib->stable_baselines3) (9.2.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\harih\anaconda3\envs\rl\lib\site-packages (from matplotlib->stable_baselines3) (4.37.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\harih\anaconda3\envs\rl\lib\site-packages (from matplotlib->stable_baselines3) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\harih\anaconda3\envs\rl\lib\site-packages (from matplotlib->stable_baselines3) (1.4.4)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\harih\anaconda3\envs\rl\lib\site-packages (from matplotlib->stable_baselines3) (3.0.4)
# Requirement already satisfied: pytz>=2020.1 in c:\users\harih\anaconda3\envs\rl\lib\site-packages (from pandas->stable_baselines3) (2022.2.1)
# Requirement already satisfied: six>=1.5 in c:\users\harih\anaconda3\envs\rl\lib\site-packages (from python-dateutil>=2.7->matplotlib->stable_baselines3) (1.16.0)

# %% [markdown]
# # DQN

# %% [markdown]
# ## Import Modules

# %%
import gym
from stable_baselines3 import PPO,DQN
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.evaluation import evaluate_policy

# %% [markdown]
# ## Environment Testing with Random Actions

# %%
env_name = 'CartPole-v1'
env = gym.make(env_name)

# %%
env.action_space.sample()
# Out:
# 0

# %%
for episode in range(1, 11):
    score = 0
    state = env.reset()
    done = False
    
    while not done:
        #env.render()
        action = env.action_space.sample()
        n_state, reward, done, info = env.step(action)
        score += reward
        
    print('Episode:', episode, 'Score:', score)
env.close()
# Out:
# Episode: 1 Score: 12.0
# Episode: 2 Score: 13.0
# Episode: 3 Score: 15.0
# Episode: 4 Score: 13.0
# Episode: 5 Score: 19.0
# Episode: 6 Score: 22.0
# Episode: 7 Score: 15.0
# Episode: 8 Score: 25.0
# Episode: 9 Score: 10.0
# Episode: 10 Score: 11.0

# %% [markdown]
# ## Model Training

# %%
env = gym.make(env_name)
env = DummyVecEnv([lambda: env])
model = DQN('MlpPolicy', env, verbose=1)
# Out:
# Using cpu device

# %%
model.learn(total_timesteps=100000)
# Out:
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.989    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 4913     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 113      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.983    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 5175     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 176      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.977    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 5534     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 238      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.968    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 6000     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 342      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.958    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 6027     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 440      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.949    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 6183     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 538      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.933    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 6173     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 710      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.923    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 5757     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 806      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.916    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 5679     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 886      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.905    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 5864     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 997      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.899    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 5878     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1064     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.892    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 5646     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1135     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.887    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 5679     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1187     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.874    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 5657     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1324     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.864    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 5707     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1427     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.856    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 5796     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1513     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.849    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 5874     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1586     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.834    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 6101     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1745     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.827    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 6187     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1819     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.82     |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 6236     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1896     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.813    |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 6324     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1967     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.805    |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 6395     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2053     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.795    |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 6474     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2156     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.787    |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 6536     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2242     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.776    |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 6599     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2356     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.764    |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 6708     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2482     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.756    |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 6755     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2567     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.748    |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 6812     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2650     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.742    |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 6841     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2716     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.735    |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 6869     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2789     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.73     |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 6853     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2844     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.722    |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 6889     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2928     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.715    |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 6892     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3005     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.704    |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 6931     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3119     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.695    |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 6982     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3212     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.685    |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 7053     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3315     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.673    |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 7109     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3441     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.66     |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 7166     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3576     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.652    |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 7220     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3668     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.646    |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 7202     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3731     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.638    |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 7252     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3815     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.626    |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 7237     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3937     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.614    |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 7253     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4062     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.605    |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 7272     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4160     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.597    |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 7292     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4237     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.591    |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 7315     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4309     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.585    |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 7344     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4370     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.575    |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 7363     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4477     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.567    |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 7355     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4553     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.56     |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 7393     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4628     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.552    |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 7339     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4719     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.545    |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 7319     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4794     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.536    |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 7286     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4882     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.529    |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 7273     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4953     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.523    |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 7206     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5023     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.516    |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 7151     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5099     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.505    |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 7048     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5209     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.495    |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 7018     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5313     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.484    |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 7012     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5428     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.473    |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 6979     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5549     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.466    |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 6941     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5616     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.461    |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 6925     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5672     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.454    |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 6937     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5744     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.445    |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 6832     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5842     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.437    |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              |
|
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0449   |
# |    n_updates        | 9007     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4532     |
# |    fps              | 1424     |
# |    time_elapsed     | 60       |
# |    total_timesteps  | 86741    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0144   |
# |    n_updates        | 9185     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4536     |
# |    fps              | 1410     |
# |    time_elapsed     | 61       |
# |    total_timesteps  | 87322    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0327   |
# |    n_updates        | 9330     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4540     |
# |    fps              | 1399     |
# |    time_elapsed     | 62       |
# |    total_timesteps  | 88048    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0564   |
# |    n_updates        | 9511     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4544     |
# |    fps              | 1389     |
# |    time_elapsed     | 63       |
# |    total_timesteps  | 88716    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0889   |
# |    n_updates        | 9678     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4548     |
# |    fps              | 1377     |
# |    time_elapsed     | 64       |
# |    total_timesteps  | 89417    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0357   |
# |    n_updates        | 9854     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4552     |
# |    fps              | 1366     |
# |    time_elapsed     | 65       |
# |    total_timesteps  | 90130    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.032    |
# |    n_updates        | 10032    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4556     |
# |    fps              | 1356     |
# |    time_elapsed     | 66       |
# |    total_timesteps  | 90668    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0685   |
# |    n_updates        | 10166    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4560     |
# |    fps              | 1343     |
# |    time_elapsed     | 68       |
# |    total_timesteps  | 91483    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.071    |
# |    n_updates        | 10370    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4564     |
# |    fps              | 1325     |
# |    time_elapsed     | 69       |
# |    total_timesteps  | 92686    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00766  |
# |    n_updates        | 10671    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4568     |
# |    fps              | 1314     |
# |    time_elapsed     | 71       |
# |    total_timesteps  | 93537    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.152    |
# |    n_updates        | 10884    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4572     |
# |    fps              | 1296     |
# |    time_elapsed     | 73       |
# |    total_timesteps  | 94704    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0854   |
# |    n_updates        | 11175    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4576     |
# |    fps              | 1284     |
# |    time_elapsed     | 74       |
# |    total_timesteps  | 95513    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.116    |
# |    n_updates        | 11378    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4580     |
# |    fps              | 1269     |
# |    time_elapsed     | 76       |
# |    total_timesteps  | 96589    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0827   |
# |    n_updates        | 11647    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4584     |
# |    fps              | 1258     |
# |    time_elapsed     | 77       |
# |    total_timesteps  | 97391    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0137   |
# |    n_updates        | 11847    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4588     |
# |    fps              | 1247     |
# |    time_elapsed     | 78       |
# |    total_timesteps  | 98179    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0745   |
# |    n_updates        | 12044    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4592     |
# |    fps              | 1239     |
# |    time_elapsed     | 79       |
# |    total_timesteps  | 98934    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0104   |
# |    n_updates        | 12233    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4596     |
# |    fps              | 1231     |
# |    time_elapsed     | 81       |
# |    total_timesteps  | 99868    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.132    |
# |    n_updates        | 12466    |
# ----------------------------------

# %%
# save the model
model.save('DQN model')

# %% [markdown]
# ## Model Testing

# %%
evaluate_policy(model, env, n_eval_episodes=10, render=False)
# Out:
# C:\Users\harih\anaconda3\envs\RL\lib\site-packages\stable_baselines3\common\evaluation.py:65: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# (231.1, 55.25296372141498)

# %%
env.close()

# %%
for episode in range(1, 11):
    score = 0
    obs = env.reset()
    done = False
    
    while not done:
        #env.render()
        action, _ = model.predict(obs)
        obs, reward, done, info = env.step(action)
        score += reward
        
    print('Episode:', episode, 'Score:', score)
env.close()
# Out:
# Episode: 1 Score: [197.]
# Episode: 2 Score: [147.]
# Episode: 3 Score: [193.]
# Episode: 4 Score: [227.]
# Episode: 5 Score: [182.]
# Episode: 6 Score: [180.]
# Episode: 7 Score: [155.]
# Episode: 8 Score: [167.]
# Episode: 9 Score: [179.]
# Episode: 10 Score: [173.]

# %% [markdown]
# # PPO

# %% [markdown]
# ## Import Modules

# %%
import gym
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.evaluation import evaluate_policy

# %% [markdown]
# ## Environment Testing with Random Actions

# %%
env_name = 'CartPole-v1'
env = gym.make(env_name)

# %%
for episode in range(1, 11):
    score = 0
    state = env.reset()
    done = False
    
    while not done:
        #env.render()
        action = env.action_space.sample()
        n_state, reward, done, info = env.step(action)
        score += reward
        
    print('Episode:', episode, 'Score:', score)
env.close()
# Out:
# Episode: 1 Score: 18.0
# Episode: 2 Score: 12.0
# Episode: 3 Score: 11.0
# Episode: 4 Score: 52.0
# Episode: 5 Score: 18.0
# Episode: 6 Score: 10.0
# Episode: 7 Score: 11.0
# Episode: 8 Score: 40.0
# Episode: 9 Score: 42.0
# Episode: 10 Score: 29.0

# %% [markdown]
# ## Model Training

# %%
env = gym.make(env_name)
env = DummyVecEnv([lambda: env])
model = PPO('MlpPolicy', env, verbose=1)
# Out:
# Using cpu device

# %%
model.learn(total_timesteps=50000)
# Out:
# -----------------------------
# | time/              |      |
# |    fps             | 1538 |
# |    iterations      | 1    |
# |    time_elapsed    | 1    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 880         |
# |    iterations           | 2           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.008195636 |
# |    clip_fraction        | 0.116       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.686      |
# |    explained_variance   | -0.00215    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.83        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0188     |
# |    value_loss           | 55.1        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 740         |
# |    iterations           | 3           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.011195593 |
# |    clip_fraction        | 0.0663      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.669      |
# |    explained_variance   | 0.0799      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 15.7        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0167     |
# |    value_loss           | 32.8        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 722         |
# |    iterations           | 4           |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.010729145 |
# |    clip_fraction        | 0.114       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.634      |
# |    explained_variance   | 0.292       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 25.2        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.022      |
# |    value_loss           | 51.4        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 711         |
# |    iterations           | 5           |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.007614054 |
# |    clip_fraction        | 0.0543      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.61       |
# |    explained_variance   | 0.294       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 25.2        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0132     |
# |    value_loss           | 64.1        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 702        |
# |    iterations           | 6          |
# |    time_elapsed         | 17         |
# |    total_timesteps      | 12288      |
# | train/                  |            |
# |    approx_kl            | 0.00924032 |
# |    clip_fraction        | 0.0895     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.6       |
# |    explained_variance   | 0.447      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 21.6       |
# |    n_updates            | 50         |
# |    policy_gradient_loss | -0.0159    |
# |    value_loss           | 57.1       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 696         |
# |    iterations           | 7           |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.004009851 |
# |    clip_fraction        | 0.0273      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.586      |
# |    explained_variance   | 0.264       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 32.6        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00924    |
# |    value_loss           | 76.1        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 693          |
# |    iterations           | 8            |
# |    time_elapsed         | 23           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0045640427 |
# |    clip_fraction        | 0.03         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.567       |
# |    explained_variance   | 0.615        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 21.2         |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00618     |
# |    value_loss           | 50           |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 680         |
# |    iterations           | 9           |
# |    time_elapsed         | 27          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.004985745 |
# |    clip_fraction        | 0.0493      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.553      |
# |    explained_variance   | 0.74        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 33.6        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00804    |
# |    value_loss           | 40.2        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 674        |
# |    iterations           | 10         |
# |    time_elapsed         | 30         |
# |    total_timesteps      | 20480      |
# | train/                  |            |
# |    approx_kl            | 0.00722545 |
# |    clip_fraction        | 0.0874     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.554     |
# |    explained_variance   | 0.915      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.08       |
# |    n_updates            | 90         |
# |    policy_gradient_loss | -0.0127    |
# |    value_loss           | 17.3       |
# ----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 667          |
# |    iterations           | 11           |
# |    time_elapsed         | 33           |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0031341896 |
# |    clip_fraction        | 0.0221       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.535       |
# |    explained_variance   | 0.124        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 51.6         |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.0071      |
# |    value_loss           | 78.6         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 664          |
# |    iterations           | 12           |
# |    time_elapsed         | 36           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0035508801 |
# |    clip_fraction        | 0.0231       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.537       |
# |    explained_variance   | 0.758        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 10.5         |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.00332     |
# |    value_loss           | 24.4         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 653          |
# |    iterations           | 13           |
# |    time_elapsed         | 40           |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0044884966 |
# |    clip_fraction        | 0.0364       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.526       |
# |    explained_variance   | 0.899        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.45         |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.00678     |
# |    value_loss           | 13.2         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 643         |
# |    iterations           | 14          |
# |    time_elapsed         | 44          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.004763094 |
# |    clip_fraction        | 0.047       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.515      |
# |    explained_variance   | 0.941       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.531       |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00459    |
# |    value_loss           | 4.33        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 635          |
# |    iterations           | 15           |
# |    time_elapsed         | 48           |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0011765733 |
# |    clip_fraction        | 0.0062       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.502       |
# |    explained_variance   | 0.21         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.08         |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.000225    |
# |    value_loss           | 22           |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 630          |
# |    iterations           | 16           |
# |    time_elapsed         | 51           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0025607555 |
# |    clip_fraction        | 0.0128       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.494       |
# |    explained_variance   | 0.17         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.28         |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.00326     |
# |    value_loss           | 57.8         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 623          |
# |    iterations           | 17           |
# |    time_elapsed         | 55           |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0054740873 |
# |    clip_fraction        | 0.0508       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.501       |
# |    explained_variance   | 0.617        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 12.7         |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.00294     |
# |    value_loss           | 8.5          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 624          |
# |    iterations           | 18           |
# |    time_elapsed         | 59           |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0055880924 |
# |    clip_fraction        | 0.062        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.501       |
# |    explained_variance   | -0.0892      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.013        |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.00231     |
# |    value_loss           | 0.567        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 620          |
# |    iterations           | 19           |
# |    time_elapsed         | 62           |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0046287463 |
# |    clip_fraction        | 0.0399       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.504       |
# |    explained_variance   | 0.856        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0448       |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.00396     |
# |    value_loss           | 0.374        |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 619         |
# |    iterations           | 20          |
# |    time_elapsed         | 66          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.005554393 |
# |    clip_fraction        | 0.0564      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.488      |
# |    explained_variance   | 0.128       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0495      |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00414    |
# |    value_loss           | 0.254       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 617         |
# |    iterations           | 21          |
# |    time_elapsed         | 69          |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.004722288 |
# |    clip_fraction        | 0.0318      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.495      |
# |    explained_variance   | 0.127       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0101      |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.00167    |
# |    value_loss           | 0.153       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 612          |
# |    iterations           | 22           |
# |    time_elapsed         | 73           |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0058044223 |
# |    clip_fraction        | 0.0649       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.49        |
# |    explained_variance   | 0.252        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0147      |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.00443     |
# |    value_loss           | 0.0963       |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 608         |
# |    iterations           | 23          |
# |    time_elapsed         | 77          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.002753005 |
# |    clip_fraction        | 0.0208      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.465      |
# |    explained_variance   | 0.28        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00602     |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.00119    |
# |    value_loss           | 0.0598      |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 609          |
# |    iterations           | 24           |
# |    time_elapsed         | 80           |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0033342128 |
# |    clip_fraction        | 0.0255       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.467       |
# |    explained_variance   | 0.174        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00447     |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.00292     |
# |    value_loss           | 0.0393       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 611          |
# |    iterations           | 25           |
# |    time_elapsed         | 83           |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0062696077 |
# |    clip_fraction        | 0.0338       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.447       |
# |    explained_variance   | 0.242        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0111       |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.00104     |
# |    value_loss           | 0.025        |
# ------------------------------------------

# %%
# save the model
model.save('PPO model')

# %% [markdown]
# ## Model Testing

# %%
evaluate_policy(model, env, n_eval_episodes=10, render=False)
# Out:
# (500.0, 0.0)

# %%
env.close()

# %%
import time
for episode in range(1, 11):
    score = 0
    obs = env.reset()
    done = False
    
    while not done:
        env.render()
        action, _ = model.predict(obs)
        obs, reward, done, info = env.step(action)
        time.sleep(0.01)
        score += reward
        
    print('Episode:', episode, 'Score:', score)
env.close()
# Out:
# Episode: 1 Score: [500.]
# Episode: 2 Score: [500.]
# Episode: 3 Score: [500.]
# Episode: 4 Score: [500.]
# Episode: 5 Score: [500.]
# Episode: 6 Score: [500.]
# Episode: 7 Score: [500.]
# Episode: 8 Score: [500.]
# Episode: 9 Score: [500.]
# Episode: 10 Score: [500.]
